# %%
rm(list = ls())
gc()

setwd("/mnt/data00/minghui/project_NMF/04_Test_NMF_Program_0120/")
library(Seurat)
library(dplyr)
library(cowplot)
library(harmony)
library(readr) 
library(tidyr)
library(gplots)
library(reshape2)
library(paletteer)
library(AUCell)
library(pheatmap)
suppressPackageStartupMessages(library(NMF))
suppressMessages(library(ggplot2))
suppressMessages(library(tidyverse))
suppressMessages(library(scibet))
suppressMessages(library(viridis))
suppressMessages(library(ggsci))
 
d_palettes<- palettes_d_names
mycol<-paletteer_d( "ggsci::default_igv",n=51)

source('/mnt/data00/minghui/Fuctions/Markers_kno.R')
source('/mnt/data00/minghui/Fuctions/seurat_functions.R')

library(ComplexHeatmap)
library(circlize)

library(scater)


library(htmlwidgets)

library(GSVA)
library(ggplot2)
library(ggsignif)
library(ggbeeswarm)
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  652777 34.9 1445934    77.3 1178160  63.0
# Vcells 1213617  9.3 8388608    64.0 1924993  14.7
# Attaching SeuratObject
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: Rcpp
#
#
# Attaching package: ‘gplots’
#
#
# The following object is masked from ‘package:stats’:
#
#     lowess
#
#
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
# Error in library(MSigDB) : there is no package called ‘MSigDB’
# Error in library(biomaRt) : there is no package called ‘biomaRt’
# Error in library(visNetwork) : there is no package called ‘visNetwork’
# Error in library(rjags) : there is no package called ‘rjags’
# Error in library(infercnv) : there is no package called ‘infercnv’
# Error in library(mHG) : there is no package called ‘mHG’
# Error in library(VennDiagram) : there is no package called ‘VennDiagram’
# Error in library(tsne) : there is no package called ‘tsne’
# Error in library(nichenetr) : there is no package called ‘nichenetr’
# Error in library(DiagrammeR) : there is no package called ‘DiagrammeR’
# Error in library(SeuratDisk) : there is no package called ‘SeuratDisk’
# Error in library(SeuratWrappers) :
#   there is no package called ‘SeuratWrappers’
# Error in library(nnls) : there is no package called ‘nnls’
# Error in library(colormap) : there is no package called ‘colormap’
# Error in library(genesorteR) : there is no package called ‘genesorteR’
# Error in library(survminer) : there is no package called ‘survminer’
# Loading required package: SingleCellExperiment
#
# Loading required package: scuttle
#
#
# Attaching package: ‘htmlwidgets’
#
#
# The following object is masked from ‘package:SeuratObject’:
#
#     JS
#
#
# The following object is masked from ‘package:Seurat’:
#
#     JS

# %%
cluster_cols <- c(
  "#DC050C", "#FB8072", "#1965B0", "#7BAFDE", "#882E72",
  "#B17BA6", "#FF7F00", "#FDB462", "#E7298A", "#E78AC3",
  "#33A02C", "#B2DF8A", "#55A1B1", "#8DD3C7", "#A6761D",
  "#E6AB02", "#7570B3", "#BEAED4", "#666666", "#999999",
  "#aa8282", "#d4b7b7", "#8600bf", "#ba5ce3", "#808000",
  "#aeae5c", "#1e90ff", "#00bfff", "#56ff0d", "#ffff00")


my36colors <- c('#53A85F', '#F1BB72', '#D6E7A3', '#57C3F3', '#476D87', '#E95C59', '#E59CC4', '#AB3282', '#23452F', '#BD956A', '#8C549C', '#585658', '#9FA3A8', '#5F3D69', '#C5DEBA', '#58A4C3', '#E4C755', '#F7F398', '#AA9A59', '#E63863', '#E39A35', '#C1E6F3', '#6778AE', '#91D0BE', '#B53E2B', '#712820', '#DCC1DD', '#CCE0F5', '#CCC9E6', '#625D9E', '#68A180', '#3A6963', '#968175', '#E5D2DD', '#E0D4CA', '#F3B1A0' )

col.list <- list(Tissuetype = c('BE-IM' = my36colors[1], 
                              'BSCJ' = my36colors[2], 
                              'CAG' = my36colors[3],
                              'CIM' = my36colors[4],
                              'Colon' = my36colors[5],
                              'E-GM' = my36colors[6],
                              'GIM' = my36colors[7],
                              'Ileum' = my36colors[8],
                              'NAG' = my36colors[9],
                              'ND' = my36colors[10],
                              'NGB' = my36colors[11],
                              'NGC' = my36colors[12],
                              'NSCJ' = my36colors[13],
                              'Rectum' = my36colors[14]
))

# %%
AllTissue_merge <- readRDS('./01_AllTissue_merge.rds')

filtered_modules_list <- readRDS('01_filtered_modules_list.rds')

# %%
DefaultAssay(AllTissue_merge) <- 'RNA'

cells_rankings <- AUCell_buildRankings(AllTissue_merge@assays$RNA@data,splitByBlocks=TRUE) 

cells_AUC <- AUCell_calcAUC(filtered_modules_list, cells_rankings, 
                            aucMaxRank=nrow(cells_rankings)*0.1)


moduleScore <- getAUC(cells_AUC)
# Out:
# Quantiles for the number of genes detected by cell:
# (Non-detected genes are shuffled at the end of the ranking. Keep it in mind when choosing the threshold for calculating the AUC).
#   min    1%    5%   10%   50%  100%
#    61   281   374   477  1582 10002
# Plot with title “”

# %%
 names(filtered_modules_list)
# Out:
#  [1] "BE_modules1"                "BE_modules3"
#  [3] "BE_modules4"                "BE_modules5"
#  [5] "BE_modules6"                "BE_modules7"
#  [7] "BE_modules8"                "BE_modules10"
#  [9] "BE_modules11"               "BE_modules12"
# [11] "BE_modules14"               "BE_modules15"
# [13] "BE_modules16"               "BE_modules17"
# [15] "BE_modules18"               "BE_modules19"
# [17] "BE_modules21"               "Healthy_intestine_modules1"
# [19] "Healthy_intestine_modules2" "Healthy_intestine_modules3"
# [21] "Healthy_intestine_modules4" "Healthy_intestine_modules5"
# [23] "Healthy_intestine_modules6" "Healthy_intestine_modules7"
# [25] "Healthy_intestine_modules8" "Healthy_stomach_modules1"
# [27] "Healthy_stomach_modules3"   "Healthy_stomach_modules4"
# [29] "Healthy_stomach_modules5"   "Healthy_stomach_modules6"
# [31] "Healthy_stomach_modules7"   "Healthy_stomach_modules8"
# [33] "Healthy_stomach_modules9"   "Healthy_stomach_modules10"
# [35] "Healthy_stomach_modules11"  "Healthy_stomach_modules12"
# [37] "Healthy_stomach_modules13"  "Healthy_stomach_modules15"
# [39] "Healthy_stomach_modules16"  "Healthy_stomach_modules17"
# [41] "Healthy_stomach_modules18"  "Healthy_stomach_modules19"
# [43] "Healthy_stomach_modules20"  "Healthy_stomach_modules21"
# [45] "Healthy_stomach_modules22"

# %%
for (geneSet in names(filtered_modules_list)) {

    AUCell_auc <- as.numeric(getAUC(cells_AUC)[geneSet, ])
  

    AllTissue_merge@meta.data[, geneSet] <- AUCell_auc
}


print(head(AllTissue_merge@meta.data))
# Out:
#                                   Sample Tissue_in_paper Batch Sample_Barcode
# SRR8513799-CTCACACGTCACCCAG-1 SRR8513799          Rectum    NA             NA
# SRR8513799-TACAGTGGTCATCCCT-1 SRR8513799          Rectum    NA             NA
# SRR8513799-GCACATACACTGTCGG-1 SRR8513799          Rectum    NA             NA
# SRR8513799-CTGAAACTCTGGCGAC-1 SRR8513799          Rectum    NA             NA
# SRR8513799-AGTAGTCAGTGAAGAG-1 SRR8513799          Rectum    NA             NA
# SRR8513799-ATCCGAACAACGATGG-1 SRR8513799          Rectum    NA             NA
#                                 sum detected             Study Patient_type
# SRR8513799-CTCACACGTCACCCAG-1  7574     1650 Wang et. al. 2020      Healthy
# SRR8513799-TACAGTGGTCATCCCT-1 19882     3503 Wang et. al. 2020      Healthy
# SRR8513799-GCACATACACTGTCGG-1 28166     4566 Wang et. al. 2020      Healthy
# SRR8513799-CTGAAACTCTGGCGAC-1 21380     3693 Wang et. al. 2020      Healthy
# SRR8513799-AGTAGTCAGTGAAGAG-1  6762     1483 Wang et. al. 2020      Healthy
# SRR8513799-ATCCGAACAACGATGG-1  8634     1876 Wang et. al. 2020      Healthy
#                               Patient_status   MT.prop sizeFactor
# SRR8513799-CTCACACGTCACCCAG-1        Healthy 10.549247   13.83808
# SRR8513799-TACAGTGGTCATCCCT-1        Healthy  4.793280   36.50897
# SRR8513799-GCACATACACTGTCGG-1        Healthy  6.522048   51.86857
# SRR8513799-CTGAAACTCTGGCGAC-1        Healthy 18.133770   38.88148
# SRR8513799-AGTAGTCAGTGAAGAG-1        Healthy  9.242828   12.43812
# SRR8513799-ATCCGAACAACGATGG-1        Healthy 11.709521   15.66922
#                               Global_cluster_selected
# SRR8513799-CTCACACGTCACCCAG-1                      18
# SRR8513799-TACAGTGGTCATCCCT-1                      28
# SRR8513799-GCACATACACTGTCGG-1                      18
# SRR8513799-CTGAAACTCTGGCGAC-1                      28
# SRR8513799-AGTAGTCAGTGAAGAG-1                      25
# SRR8513799-ATCCGAACAACGATGG-1                      25
#                                          Celltypes_global Tissuetypes_global
# SRR8513799-CTCACACGTCACCCAG-1    Enterocytes_Intermediate           Columnar
# SRR8513799-TACAGTGGTCATCCCT-1 Intestinal_Undifferentiated           Columnar
# SRR8513799-GCACATACACTGTCGG-1    Enterocytes_Intermediate           Columnar
# SRR8513799-CTGAAACTCTGGCGAC-1 Intestinal_Undifferentiated           Columnar
# SRR8513799-AGTAGTCAGTGAAGAG-1                      Goblet           Columnar
# SRR8513799-ATCCGAACAACGATGG-1                      Goblet           Columnar
#                                        Detailed_Cell_Type
# SRR8513799-CTCACACGTCACCCAG-1    Enterocytes_Intermediate
# SRR8513799-TACAGTGGTCATCCCT-1 Intestinal_Undifferentiated
# SRR8513799-GCACATACACTGTCGG-1    Enterocytes_Intermediate
# SRR8513799-CTGAAACTCTGGCGAC-1 Intestinal_Undifferentiated
# SRR8513799-AGTAGTCAGTGAAGAG-1                      Goblet
# SRR8513799-ATCCGAACAACGATGG-1                      Goblet
#                               cell_type_ontology_term_id assay_ontology_term_id
# SRR8513799-CTCACACGTCACCCAG-1                 CL:0000584            EFO:0009899
# SRR8513799-TACAGTGGTCATCCCT-1                 CL:0000034            EFO:0009899
# SRR8513799-GCACATACACTGTCGG-1                 CL:0000584            EFO:0009899
# SRR8513799-CTGAAACTCTGGCGAC-1                 CL:0000034            EFO:0009899
# SRR8513799-AGTAGTCAGTGAAGAG-1                 CL:0019031            EFO:0009899
# SRR8513799-ATCCGAACAACGATGG-1                 CL:0019031            EFO:0009899
#                               tissue_ontology_term_id disease_ontology_term_id
# SRR8513799-CTCACACGTCACCCAG-1          UBERON:0001052             PATO:0000461
# SRR8513799-TACAGTGGTCATCCCT-1          UBERON:0001052             PATO:0000461
# SRR8513799-GCACATACACTGTCGG-1          UBERON:0001052             PATO:0000461
# SRR8513799-CTGAAACTCTGGCGAC-1          UBERON:0001052             PATO:0000461
# SRR8513799-AGTAGTCAGTGAAGAG-1          UBERON:0001052             PATO:0000461
# SRR8513799-ATCCGAACAACGATGG-1          UBERON:0001052             PATO:0000461
#                               sex_ontology_term_id organism_ontology_term_id
# SRR8513799-CTCACACGTCACCCAG-1         PATO:0000383            NCBITaxon:9606
# SRR8513799-TACAGTGGTCATCCCT-1         PATO:0000383            NCBITaxon:9606
# SRR8513799-GCACATACACTGTCGG-1         PATO:0000383            NCBITaxon:9606
# SRR8513799-CTGAAACTCTGGCGAC-1         PATO:0000383            NCBITaxon:9606
# SRR8513799-AGTAGTCAGTGAAGAG-1         PATO:0000383            NCBITaxon:9606
# SRR8513799-ATCCGAACAACGATGG-1         PATO:0000383            NCBITaxon:9606
#                               self_reported_ethnicity_ontology_term_id donor_id
# SRR8513799-CTCACACGTCACCCAG-1                                  unknown   Wang06
# SRR8513799-TACAGTGGTCATCCCT-1                                  unknown   Wang06
# SRR8513799-GCACATACACTGTCGG-1                                  unknown   Wang06
# SRR8513799-CTGAAACTCTGGCGAC-1                                  unknown   Wang06
# SRR8513799-AGTAGTCAGTGAAGAG-1                                  unknown   Wang06
# SRR8513799-ATCCGAACAACGATGG-1                                  unknown   Wang06
#                               Columnar_clusters suspension_type
# SRR8513799-CTCACACGTCACCCAG-1                 9            cell
# SRR8513799-TACAGTGGTCATCCCT-1                20            cell
# SRR8513799-GCACATACACTGTCGG-1                 9            cell
# SRR8513799-CTGAAACTCTGGCGAC-1                20            cell
# SRR8513799-AGTAGTCAGTGAAGAG-1                17            cell
# SRR8513799-ATCCGAACAACGATGG-1                17            cell
#                               development_stage_ontology_term_id
# SRR8513799-CTCACACGTCACCCAG-1                     HsapDv:0000144
# SRR8513799-TACAGTGGTCATCCCT-1                     HsapDv:0000144
# SRR8513799-GCACATACACTGTCGG-1                     HsapDv:0000144
# SRR8513799-CTGAAACTCTGGCGAC-1                     HsapDv:0000144
# SRR8513799-AGTAGTCAGTGAAGAG-1                     HsapDv:0000144
# SRR8513799-ATCCGAACAACGATGG-1                     HsapDv:0000144
#                               is_primary_data tissue_type             cell_type
# SRR8513799-CTCACACGTCACCCAG-1           FALSE      tissue            enterocyte
# SRR8513799-TACAGTGGTCATCCCT-1           FALSE      tissue             stem cell
# SRR8513799-GCACATACACTGTCGG-1           FALSE      tissue            enterocyte
# SRR8513799-CTGAAACTCTGGCGAC-1           FALSE      tissue             stem cell
# SRR8513799-AGTAGTCAGTGAAGAG-1           FALSE      tissue intestine goblet cell
# SRR8513799-ATCCGAACAACGATGG-1           FALSE      tissue intestine goblet cell
#                                   assay disease     organism    sex tissue
# SRR8513799-CTCACACGTCACCCAG-1 10x 3' v2  normal Homo sapiens female rectum
# SRR8513799-TACAGTGGTCATCCCT-1 10x 3' v2  normal Homo sapiens female rectum
# SRR8513799-GCACATACACTGTCGG-1 10x 3' v2  normal Homo sapiens female rectum
# SRR8513799-CTGAAACTCTGGCGAC-1 10x 3' v2  normal Homo sapiens female rectum
# SRR8513799-AGTAGTCAGTGAAGAG-1 10x 3' v2  normal Homo sapiens female rectum
# SRR8513799-ATCCGAACAACGATGG-1 10x 3' v2  normal Homo sapiens female rectum
#                               self_reported_ethnicity development_stage
# SRR8513799-CTCACACGTCACCCAG-1                 unknown 50-year-old stage
# SRR8513799-TACAGTGGTCATCCCT-1                 unknown 50-year-old stage
# SRR8513799-GCACATACACTGTCGG-1                 unknown 50-year-old stage
# SRR8513799-CTGAAACTCTGGCGAC-1                 unknown 50-year-old stage
# SRR8513799-AGTAGTCAGTGAAGAG-1                 unknown 50-year-old stage
# SRR8513799-ATCCGAACAACGATGG-1                 unknown 50-year-old stage
#                               observation_joinid sample_name RNA_snn_res.0.5
# SRR8513799-CTCACACGTCACCCAG-1         2HF>I3*C*+  SRR8513799              27
# SRR8513799-TACAGTGGTCATCCCT-1         9(9=$HrBJH  SRR8513799              27
# SRR8513799-GCACATACACTGTCGG-1         y32y2pofxP  SRR8513799              27
# SRR8513799-CTGAAACTCTGGCGAC-1         {u=$Kcepoe  SRR8513799               9
# SRR8513799-AGTAGTCAGTGAAGAG-1         `<T_#t6_AO  SRR8513799              19
# SRR8513799-ATCCGAACAACGATGG-1         %9W<c>cqqW  SRR8513799              19
#                               seurat_clusters nCount_RNA nFeature_RNA
# SRR8513799-CTCACACGTCACCCAG-1              27       7250         1586
# SRR8513799-TACAGTGGTCATCCCT-1              27      19174         3375
# SRR8513799-GCACATACACTGTCGG-1              27      27241         4396
# SRR8513799-CTGAAACTCTGGCGAC-1               9      20407         3550
# SRR8513799-AGTAGTCAGTGAAGAG-1              19       6535         1434
# SRR8513799-ATCCGAACAACGATGG-1              19       8228         1824
#                               nCount_module_AUC nFeature_module_AUC BE_modules1
# SRR8513799-CTCACACGTCACCCAG-1          14.28894                  44   0.1511667
# SRR8513799-TACAGTGGTCATCCCT-1          13.89324                  43   0.1539813
# SRR8513799-GCACATACACTGTCGG-1          13.74449                  43   0.1607785
# SRR8513799-CTGAAACTCTGGCGAC-1          13.06973                  45   0.1906623
# SRR8513799-AGTAGTCAGTGAAGAG-1          12.75615                  42   0.1788707
# SRR8513799-ATCCGAACAACGATGG-1          13.94309                  44   0.1098500
#                               BE_modules3 BE_modules4 BE_modules5 BE_modules6
# SRR8513799-CTCACACGTCACCCAG-1   0.2343502  0.03947408   0.2170138   0.2389288
# SRR8513799-TACAGTGGTCATCCCT-1   0.2411606  0.19631976   0.2658685   0.2810902
# SRR8513799-GCACATACACTGTCGG-1   0.2085083  0.14964128   0.2064760   0.3022502
# SRR8513799-CTGAAACTCTGGCGAC-1   0.1815468  0.11887251   0.3184584   0.2393831
# SRR8513799-AGTAGTCAGTGAAGAG-1   0.1697920  0.18455258   0.1643744   0.2204310
# SRR8513799-ATCCGAACAACGATGG-1   0.2331841  0.34055774   0.1891852   0.4190471
#                               BE_modules7 BE_modules8 BE_modules10 BE_modules11
# SRR8513799-CTCACACGTCACCCAG-1   0.4420290   0.1773295    0.6031043   0.15996591
# SRR8513799-TACAGTGGTCATCCCT-1   0.5416579   0.1265844    0.3722907   0.13713240
# SRR8513799-GCACATACACTGTCGG-1   0.5382623   0.1616739    0.3585705   0.11672138
# SRR8513799-CTGAAACTCTGGCGAC-1   0.4587272   0.1118621    0.2012800   0.29758169
# SRR8513799-AGTAGTCAGTGAAGAG-1   0.3457607   0.1548246    0.3672225   0.07853141
# SRR8513799-ATCCGAACAACGATGG-1   0.5981587   0.3171308    0.3195095   0.07632965
#                               BE_modules12 BE_modules14 BE_modules15
# SRR8513799-CTCACACGTCACCCAG-1   0.15470060   0.10083893    0.7764792
# SRR8513799-TACAGTGGTCATCCCT-1   0.11744558   0.06568792    0.8265934
# SRR8513799-GCACATACACTGTCGG-1   0.14185612   0.02919463    0.8078027
# SRR8513799-CTGAAACTCTGGCGAC-1   0.11549177   0.08288591    0.8406389
# SRR8513799-AGTAGTCAGTGAAGAG-1   0.06166556   0.00000000    0.7479912
# SRR8513799-ATCCGAACAACGATGG-1   0.04691552   0.19278523    0.4894083
#                               BE_modules16 BE_modules17 BE_modules18
# SRR8513799-CTCACACGTCACCCAG-1   0.18638369    0.1798477    0.9770532
# SRR8513799-TACAGTGGTCATCCCT-1   0.16861285    0.2104930    0.9336413
# SRR8513799-GCACATACACTGTCGG-1   0.17539699    0.2306453    0.9773968
# SRR8513799-CTGAAACTCTGGCGAC-1   0.21640201    0.1535264    0.9879348
# SRR8513799-AGTAGTCAGTGAAGAG-1   0.14997148    0.5100428    0.9764805
# SRR8513799-ATCCGAACAACGATGG-1   0.07483565    0.5505363    0.9887366
#                               BE_modules19 BE_modules21
# SRR8513799-CTCACACGTCACCCAG-1   0.31900063    0.4443129
# SRR8513799-TACAGTGGTCATCCCT-1   0.28045350    0.2628002
# SRR8513799-GCACATACACTGTCGG-1   0.24728113    0.3550838
# SRR8513799-CTGAAACTCTGGCGAC-1   0.20386311    0.1863235
# SRR8513799-AGTAGTCAGTGAAGAG-1   0.22565610    0.4081173
# SRR8513799-ATCCGAACAACGATGG-1   0.05194205    0.5013172
#                               Healthy_intestine_modules1
# SRR8513799-CTCACACGTCACCCAG-1                  0.8473503
# SRR8513799-TACAGTGGTCATCCCT-1                  0.8770618
# SRR8513799-GCACATACACTGTCGG-1                  0.8783955
# SRR8513799-CTGAAACTCTGGCGAC-1                  0.8867097
# SRR8513799-AGTAGTCAGTGAAGAG-1                  0.8372945
# SRR8513799-ATCCGAACAACGATGG-1                  0.6456932
#                               Healthy_intestine_modules2
# SRR8513799-CTCACACGTCACCCAG-1                  0.3751033
# SRR8513799-TACAGTGGTCATCCCT-1                  0.4525611
# SRR8513799-GCACATACACTGTCGG-1                  0.4638557
# SRR8513799-CTGAAACTCTGGCGAC-1                  0.3718300
# SRR8513799-AGTAGTCAGTGAAGAG-1                  0.3878401
# SRR8513799-ATCCGAACAACGATGG-1                  0.7321223
#                               Healthy_intestine_modules3
# SRR8513799-CTCACACGTCACCCAG-1                  0.4375144
# SRR8513799-TACAGTGGTCATCCCT-1                  0.3391893
# SRR8513799-GCACATACACTGTCGG-1                  0.4226966
# SRR8513799-CTGAAACTCTGGCGAC-1                  0.2078255
# SRR8513799-AGTAGTCAGTGAAGAG-1                  0.3920310
# SRR8513799-ATCCGAACAACGATGG-1                  0.2794860
#                               Healthy_intestine_modules4
# SRR8513799-CTCACACGTCACCCAG-1                  0.6587155
# SRR8513799-TACAGTGGTCATCCCT-1                  0.4657416
# SRR8513799-GCACATACACTGTCGG-1                  0.4455061
# SRR8513799-CTGAAACTCTGGCGAC-1                  0.3363448
# SRR8513799-AGTAGTCAGTGAAGAG-1                  0.4055983
# SRR8513799-ATCCGAACAACGATGG-1                  0.3115813
#                               Healthy_intestine_modules5
# SRR8513799-CTCACACGTCACCCAG-1                  0.4285939
# SRR8513799-TACAGTGGTCATCCCT-1                  0.4395593
# SRR8513799-GCACATACACTGTCGG-1                  0.2154774
# SRR8513799-CTGAAACTCTGGCGAC-1                  0.1474816
# SRR8513799-AGTAGTCAGTGAAGAG-1                  0.3691501
# SRR8513799-ATCCGAACAACGATGG-1                  0.4100210
#                               Healthy_intestine_modules6
# SRR8513799-CTCACACGTCACCCAG-1                  0.3792057
# SRR8513799-TACAGTGGTCATCCCT-1                  0.3126488
# SRR8513799-GCACATACACTGTCGG-1                  0.3020775
# SRR8513799-CTGAAACTCTGGCGAC-1                  0.6028625
# SRR8513799-AGTAGTCAGTGAAGAG-1                  0.1926232
# SRR8513799-ATCCGAACAACGATGG-1                  0.1520524
#                               Healthy_intestine_modules7
# SRR8513799-CTCACACGTCACCCAG-1                  0.1856608
# SRR8513799-TACAGTGGTCATCCCT-1                  0.2245201
# SRR8513799-GCACATACACTGTCGG-1                  0.2319376
# SRR8513799-CTGAAACTCTGGCGAC-1                  0.3615127
# SRR8513799-AGTAGTCAGTGAAGAG-1                  0.2445807
# SRR8513799-ATCCGAACAACGATGG-1                  0.1515178
#                               Healthy_intestine_modules8
# SRR8513799-CTCACACGTCACCCAG-1                  0.9968534
# SRR8513799-TACAGTGGTCATCCCT-1                  0.9791623
# SRR8513799-GCACATACACTGTCGG-1                  0.9902804
# SRR8513799-CTGAAACTCTGGCGAC-1                  0.9990910
# SRR8513799-AGTAGTCAGTGAAGAG-1                  0.9930075
# SRR8513799-ATCCGAACAACGATGG-1                  0.9960842
#                               Healthy_stomach_modules1 Healthy_stomach_modules3
# SRR8513799-CTCACACGTCACCCAG-1                0.3385772                0.4266131
# SRR8513799-TACAGTGGTCATCCCT-1                0.2662164                0.2807296
# SRR8513799-GCACATACACTGTCGG-1                0.2742248                0.2326097
# SRR8513799-CTGAAACTCTGGCGAC-1                0.2210581                0.1474345
# SRR8513799-AGTAGTCAGTGAAGAG-1                0.1772278                0.2706753
# SRR8513799-ATCCGAACAACGATGG-1                0.3315057                0.2171596
#                               Healthy_stomach_modules4 Healthy_stomach_modules5
# SRR8513799-CTCACACGTCACCCAG-1                0.3867039               0.00000000
# SRR8513799-TACAGTGGTCATCCCT-1                0.4580307               0.03994548
# SRR8513799-GCACATACACTGTCGG-1                0.4907336               0.16449990
# SRR8513799-CTGAAACTCTGGCGAC-1                0.5212623               0.01562172
# SRR8513799-AGTAGTCAGTGAAGAG-1                0.3620209               0.22625288
# SRR8513799-ATCCGAACAACGATGG-1                0.2622860               0.58565737
#                               Healthy_stomach_modules6 Healthy_stomach_modules7
# SRR8513799-CTCACACGTCACCCAG-1                0.2437105               0.00000000
# SRR8513799-TACAGTGGTCATCCCT-1                0.2415460               0.08809024
# SRR8513799-GCACATACACTGTCGG-1                0.2518495               0.09249738
# SRR8513799-CTGAAACTCTGGCGAC-1                0.1719783               0.05146905
# SRR8513799-AGTAGTCAGTGAAGAG-1                0.2383499               0.13667366
# SRR8513799-ATCCGAACAACGATGG-1                0.2207400               0.10776495
#                               Healthy_stomach_modules8 Healthy_stomach_modules9
# SRR8513799-CTCACACGTCACCCAG-1                0.5847969                0.6987578
# SRR8513799-TACAGTGGTCATCCCT-1                0.5730470                0.7213115
# SRR8513799-GCACATACACTGTCGG-1                0.5796270                0.7247123
# SRR8513799-CTGAAACTCTGGCGAC-1                0.5935289                0.7293807
# SRR8513799-AGTAGTCAGTGAAGAG-1                0.6181913                0.7069749
# SRR8513799-ATCCGAACAACGATGG-1                0.5881858                0.5151329
#                               Healthy_stomach_modules10
# SRR8513799-CTCACACGTCACCCAG-1                 0.3184066
# SRR8513799-TACAGTGGTCATCCCT-1                 0.3532909
# SRR8513799-GCACATACACTGTCGG-1                 0.3921254
# SRR8513799-CTGAAACTCTGGCGAC-1                 0.3432029
# SRR8513799-AGTAGTCAGTGAAGAG-1                 0.2828858
# SRR8513799-ATCCGAACAACGATGG-1                 0.4555266
#                               Healthy_stomach_modules11
# SRR8513799-CTCACACGTCACCCAG-1                 0.3423150
# SRR8513799-TACAGTGGTCATCCCT-1                 0.5115328
# SRR8513799-GCACATACACTGTCGG-1                 0.3578318
# SRR8513799-CTGAAACTCTGGCGAC-1                 0.4599497
# SRR8513799-AGTAGTCAGTGAAGAG-1                 0.1169008
# SRR8513799-ATCCGAACAACGATGG-1                 0.4332145
#                               Healthy_stomach_modules12
# SRR8513799-CTCACACGTCACCCAG-1                 0.1856403
# SRR8513799-TACAGTGGTCATCCCT-1                 0.4023664
# SRR8513799-GCACATACACTGTCGG-1                 0.1105860
# SRR8513799-CTGAAACTCTGGCGAC-1                 0.1521739
# SRR8513799-AGTAGTCAGTGAAGAG-1                 0.1054750
# SRR8513799-ATCCGAACAACGATGG-1                 0.2946860
#                               Healthy_stomach_modules13
# SRR8513799-CTCACACGTCACCCAG-1                0.00000000
# SRR8513799-TACAGTGGTCATCCCT-1                0.00000000
# SRR8513799-GCACATACACTGTCGG-1                0.08555253
# SRR8513799-CTGAAACTCTGGCGAC-1                0.02212204
# SRR8513799-AGTAGTCAGTGAAGAG-1                0.00000000
# SRR8513799-ATCCGAACAACGATGG-1                0.18043615
#                               Healthy_stomach_modules15
# SRR8513799-CTCACACGTCACCCAG-1               0.000000000
# SRR8513799-TACAGTGGTCATCCCT-1               0.004180478
# SRR8513799-GCACATACACTGTCGG-1               0.058180379
# SRR8513799-CTGAAACTCTGGCGAC-1               0.007074655
# SRR8513799-AGTAGTCAGTGAAGAG-1               0.036535893
# SRR8513799-ATCCGAACAACGATGG-1               0.031143324
#                               Healthy_stomach_modules16
# SRR8513799-CTCACACGTCACCCAG-1                0.20123652
# SRR8513799-TACAGTGGTCATCCCT-1                0.16511706
# SRR8513799-GCACATACACTGTCGG-1                0.15925307
# SRR8513799-CTGAAACTCTGGCGAC-1                0.35775419
# SRR8513799-AGTAGTCAGTGAAGAG-1                0.12915013
# SRR8513799-ATCCGAACAACGATGG-1                0.08555323
#                               Healthy_stomach_modules17
# SRR8513799-CTCACACGTCACCCAG-1                0.06159496
# SRR8513799-TACAGTGGTCATCCCT-1                0.08856243
# SRR8513799-GCACATACACTGTCGG-1                0.18321091
# SRR8513799-CTGAAACTCTGGCGAC-1                0.07182581
# SRR8513799-AGTAGTCAGTGAAGAG-1                0.12660021
# SRR8513799-ATCCGAACAACGATGG-1                0.32056663
#                               Healthy_stomach_modules18
# SRR8513799-CTCACACGTCACCCAG-1                0.05025065
# SRR8513799-TACAGTGGTCATCCCT-1                0.04727884
# SRR8513799-GCACATACACTGTCGG-1                0.07312461
# SRR8513799-CTGAAACTCTGGCGAC-1                0.00000000
# SRR8513799-AGTAGTCAGTGAAGAG-1                0.09752949
# SRR8513799-ATCCGAACAACGATGG-1                0.06318855
#                               Healthy_stomach_modules19
# SRR8513799-CTCACACGTCACCCAG-1                0.07653490
# SRR8513799-TACAGTGGTCATCCCT-1                0.10707573
# SRR8513799-GCACATACACTGTCGG-1                0.12328957
# SRR8513799-CTGAAACTCTGGCGAC-1                0.12952792
# SRR8513799-AGTAGTCAGTGAAGAG-1                0.13526895
# SRR8513799-ATCCGAACAACGATGG-1                0.09266099
#                               Healthy_stomach_modules20
# SRR8513799-CTCACACGTCACCCAG-1                0.08500689
# SRR8513799-TACAGTGGTCATCCCT-1                0.06528386
# SRR8513799-GCACATACACTGTCGG-1                0.00000000
# SRR8513799-CTGAAACTCTGGCGAC-1                0.00000000
# SRR8513799-AGTAGTCAGTGAAGAG-1                0.00000000
# SRR8513799-ATCCGAACAACGATGG-1                0.00000000
#                               Healthy_stomach_modules21
# SRR8513799-CTCACACGTCACCCAG-1               0.002731666
# SRR8513799-TACAGTGGTCATCCCT-1               0.029207817
# SRR8513799-GCACATACACTGTCGG-1               0.000000000
# SRR8513799-CTGAAACTCTGGCGAC-1               0.071113379
# SRR8513799-AGTAGTCAGTGAAGAG-1               0.002971813
# SRR8513799-ATCCGAACAACGATGG-1               0.000000000
#                               Healthy_stomach_modules22
# SRR8513799-CTCACACGTCACCCAG-1                0.20124693
# SRR8513799-TACAGTGGTCATCCCT-1                0.07943169
# SRR8513799-GCACATACACTGTCGG-1                0.09639710
# SRR8513799-CTGAAACTCTGGCGAC-1                0.08824411
# SRR8513799-AGTAGTCAGTGAAGAG-1                0.11941730
# SRR8513799-ATCCGAACAACGATGG-1                0.05209520

# %%
GeomSplitViolin <- ggproto("GeomSplitViolin", GeomViolin, 
                           draw_group = function(self, data, ..., draw_quantiles = NULL) {
  data <- transform(data, xminv = x - violinwidth * (x - xmin), xmaxv = x + violinwidth * (xmax - x))
  grp <- data[1, "group"]
  newdata <- plyr::arrange(transform(data, x = if (grp %% 2 == 1) xminv else xmaxv), if (grp %% 2 == 1) y else -y)
  newdata <- rbind(newdata[1, ], newdata, newdata[nrow(newdata), ], newdata[1, ])
  newdata[c(1, nrow(newdata) - 1, nrow(newdata)), "x"] <- round(newdata[1, "x"])

  if (length(draw_quantiles) > 0 & !scales::zero_range(range(data$y))) {
    stopifnot(all(draw_quantiles >= 0), all(draw_quantiles <=
      1))
    quantiles <- ggplot2:::create_quantile_segment_frame(data, draw_quantiles)
    aesthetics <- data[rep(1, nrow(quantiles)), setdiff(names(data), c("x", "y")), drop = FALSE]
    aesthetics$alpha <- rep(1, nrow(quantiles))
    both <- cbind(quantiles, aesthetics)
    quantile_grob <- GeomPath$draw_panel(both, ...)
    ggplot2:::ggname("geom_split_violin", grid::grobTree(GeomPolygon$draw_panel(newdata, ...), quantile_grob))
  }
  else {
    ggplot2:::ggname("geom_split_violin", GeomPolygon$draw_panel(newdata, ...))
  }
})

geom_split_violin <- function(mapping = NULL, data = NULL, stat = "ydensity", position = "identity", ..., 
                              draw_quantiles = NULL, trim = TRUE, scale = "area", na.rm = FALSE, 
                              show.legend = NA, inherit.aes = TRUE) {
  layer(data = data, mapping = mapping, stat = stat, geom = GeomSplitViolin, 
        position = position, show.legend = show.legend, inherit.aes = inherit.aes, 
        params = list(trim = trim, scale = scale, draw_quantiles = draw_quantiles, na.rm = na.rm, ...))
}

# %%
names(filtered_modules_list)[1]
# Out:
# [1] "BE_modules1"

# %%
options(repr.plot.height = 5, repr.plot.width = 20)

vplot1 <- ggplot(AllTissue_merge@meta.data, aes_string(x = 'Tissue_in_paper', y = names(filtered_modules_list)[1], fill = 'Detailed_Cell_Type')) +
#   ggtitle(names(filtered_modules_list)[1]) + 
  geom_split_violin(trim = TRUE, colour = NA) +
  geom_point(stat = 'summary', fun = mean, position = position_dodge(width = 0.9)) +
  stat_summary(fun.min = function(x) { quantile(x)[2] },
               fun.max = function(x) { quantile(x)[4] },
               geom = 'errorbar', color = 'black', width = 0.01, size = 0.5,
               position = position_dodge(width = 0.9)) +
  theme_bw() +
  theme(axis.text.x = element_text(size = 17),  
        axis.text.y = element_text(size = 16), 
        axis.title = element_text(size = 16), 
        legend.text = element_text(size = 15),
        legend.title = element_text(size = 15),
        axis.line = element_line(size = 0.7), 
        panel.border = element_blank(),
        panel.grid = element_blank()) +
  scale_fill_manual(values = cluster_cols) +
  stat_compare_means(aes(group = Detailed_Cell_Type), data = AllTissue_merge@meta.data, label = "p.signif", label.x = 1.5, size = 6)  # 增大检验标签的大小

print(vplot1)
# Out:
# Warning message:
# “`aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.”
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”
# Warning message:
# “The `size` argument of `element_line()` is deprecated as of ggplot2 3.4.0.
# ℹ Please use the `linewidth` argument instead.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# plot without title

# %%
plot_list <- list()

for (i in seq_along(filtered_modules_list)) {
  module_name <- names(filtered_modules_list)[i]
  plot <- ggplot(AllTissue_merge@meta.data, aes_string(x = 'Tissue_in_paper', y = module_name, fill = 'Detailed_Cell_Type')) +
    ggtitle(module_name) + 
    geom_split_violin(trim = TRUE, colour = NA) +
    geom_point(stat = 'summary', fun = mean, position = position_dodge(width = 0.9)) +
    stat_summary(fun.min = function(x) { quantile(x)[2] },
                 fun.max = function(x) { quantile(x)[4] },
                 geom = 'errorbar', color = 'black', width = 0.01, size = 0.5,
                 position = position_dodge(width = 0.9)) +
    theme_bw() +
    theme(axis.text.x = element_text(size = 17),  
          axis.text.y = element_text(size = 16), 
          axis.title = element_text(size = 16), 
          legend.text = element_text(size = 15),
          legend.title = element_text(size = 15),
          axis.line = element_line(size = 0.7), 
          panel.border = element_blank(),
          panel.grid = element_blank()) +
    scale_fill_manual(values = cluster_cols) +
    stat_compare_means(aes(group = Detailed_Cell_Type), data = AllTissue_merge@meta.data, label = "p.signif", label.x = 1.5, size = 6)
  
  plot_list[[i]] <- plot
}

# %%
library(gridExtra)
# Out:
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     combine
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
plot_list <- list()

for (i in seq_along(filtered_modules_list)) {
  module_name <- names(filtered_modules_list)[i]
  plot <- ggplot(AllTissue_merge@meta.data, aes_string(x = 'Tissue_in_paper', y = module_name, fill = 'Detailed_Cell_Type')) +
    ggtitle(module_name) + 
    geom_split_violin(trim = TRUE, colour = NA) +
    geom_point(stat = 'summary', fun = mean, position = position_dodge(width = 0.9)) +
    stat_summary(fun.min = function(x) { quantile(x)[2] },
                 fun.max = function(x) { quantile(x)[4] },
                 geom = 'errorbar', color = 'black', width = 0.01, size = 0.5,
                 position = position_dodge(width = 0.9)) +
    theme_bw() +
    theme(axis.text.x = element_text(size = 17),  
          axis.text.y = element_text(size = 16), 
          axis.title = element_text(size = 16), 
          legend.text = element_text(size = 15),
          legend.title = element_text(size = 15),
          axis.line = element_line(size = 0.7), 
          panel.border = element_blank(),
          panel.grid = element_blank(),
          legend.position = "none") +  # This line removes the legend
    scale_fill_manual(values = cluster_cols) +
    stat_compare_means(aes(group = Detailed_Cell_Type), data = AllTissue_merge@meta.data, label = "p.signif", label.x = 1.5, size = 6)
  
  plot_list[[i]] <- plot
}

# %%
length(plot_list)
# Out:
# [1] 45

# %%
do.call(grid.arrange, c(plot_list, ncol=5))
# Out:
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ...
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
# Warning message:
# “Groups with fewer than two datapoints have been dropped.
# ℹ Set `drop = FALSE` to consider such groups for position adjustment purposes.”
